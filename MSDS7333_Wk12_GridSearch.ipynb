# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
count=5000
data=pd.read_csv("HIGGS.csv",nrows=count,header=None)
test=pd.read_csv("HIGGS.csv",nrows=count,skiprows=10500000,header=None)

# %%
X_train=data.loc[:,1:]
y_train=data.loc[:,0]
X_test=test.loc[:,1:]
y_test=test.loc[:,0]

# %%
tuned_parameters={'n_estimators':[10,20,30,40]}
scores = ['precision', 'recall']

# %%
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'n_estimators': 40}
#
# Grid scores on development set:
#
# 0.651 (+/-0.013) for {'n_estimators': 10}
# 0.671 (+/-0.020) for {'n_estimators': 20}
# 0.676 (+/-0.025) for {'n_estimators': 30}
# 0.682 (+/-0.029) for {'n_estimators': 40}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.67      0.67      2352
#         1.0       0.71      0.71      0.71      2648
#
# avg / total       0.69      0.69      0.69      5000
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'n_estimators': 30}
#
# Grid scores on development set:
#
# 0.641 (+/-0.018) for {'n_estimators': 10}
# 0.663 (+/-0.023) for {'n_estimators': 20}
# 0.682 (+/-0.025) for {'n_estimators': 30}
# 0.682 (+/-0.037) for {'n_estimators': 40}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.67      0.66      0.66      2352
#         1.0       0.70      0.71      0.71      2648
#
# avg / total       0.69      0.69      0.69      5000

# %%
clf.cv_results_
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'mean_fit_time': array([0.12608089, 0.2456111 , 0.36741595, 0.49885654]),
#  'mean_score_time': array([0.00297742, 0.00494852, 0.0068635 , 0.008676  ]),
#  'mean_test_score': array([0.64099114, 0.66324766, 0.68220492, 0.6818336 ]),
#  'mean_train_score': array([0.98900375, 0.99902268, 0.99951134, 0.99989954]),
#  'param_n_estimators': masked_array(data=[10, 20, 30, 40],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 10},
#   {'n_estimators': 20},
#   {'n_estimators': 30},
#   {'n_estimators': 40}],
#  'rank_test_score': array([4, 3, 1, 2], dtype=int32),
#  'split0_test_score': array([0.64833791, 0.68378181, 0.69983604, 0.71696324]),
#  'split0_train_score': array([0.98701295, 0.99872711, 0.99949768, 1.        ]),
#  'split1_test_score': array([0.63520921, 0.66245921, 0.67088618, 0.67515793]),
#  'split1_train_score': array([0.98862239, 0.99926359, 0.99926359, 1.        ]),
#  'split2_test_score': array([0.62982431, 0.64919387, 0.67301201, 0.66296555]),
#  'split2_train_score': array([0.98919303, 0.99832727, 0.99973176, 0.99976592]),
#  'split3_test_score': array([0.63751185, 0.65713459, 0.69503786, 0.67515793]),
#  'split3_train_score': array([0.98802262, 0.99976592, 0.99953184, 0.99973176]),
#  'split4_test_score': array([0.65407243, 0.6636688 , 0.6722525 , 0.67892334]),
#  'split4_train_score': array([0.99216778, 0.99902951, 0.99953184, 1.        ]),
#  'std_fit_time': array([0.00500087, 0.00163671, 0.00270977, 0.01029349]),
#  'std_score_time': array([0.00014523, 0.00015684, 0.00037986, 0.00060799]),
#  'std_test_score': array([0.0088919 , 0.01146585, 0.01254763, 0.01837223]),
#  'std_train_score': array([0.00173887, 0.0004861 , 0.00014899, 0.00012352])}

# %%
tuned_parameters={'n_estimators':[10,20,30,40,50,100], 'criterion':['gini','entropy'], 'max_depth':[5,10,15],
                 'min_samples_split':[2,4,9]}

# %%
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100}
#
# Grid scores on development set:
#
# 0.662 (+/-0.030) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 10}
# 0.668 (+/-0.028) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 20}
# 0.670 (+/-0.029) for {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2, 'n_estimators':
for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 40}
# 0.683 (+/-0.028) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 50}
# 0.692 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 15, 'min_samples_split': 9, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.70      0.65      0.67      2352
#         1.0       0.71      0.75      0.73      2648
#
# avg / total       0.70      0.70      0.70      5000

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = RandomizedSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score,n_iter=10)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
#
# Grid scores on development set:
#
# 0.690 (+/-0.026) for {'n_estimators': 100, 'min_samples_split': 9, 'max_depth': 15, 'criterion': 'entropy'}
# 0.692 (+/-0.023) for {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
# 0.676 (+/-0.046) for {'n_estimators': 50, 'min_samples_split': 9, 'max_depth': 5, 'criterion': 'entropy'}
# 0.681 (+/-0.013) for {'n_estimators': 30, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
# 0.642 (+/-0.015) for {'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'gini'}
# 0.652 (+/-0.040) for {'n_estimators': 10, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'entropy'}
# 0.690 (+/-0.034) for {'n_estimators': 100, 'min_samples_split': 9, 'max_depth': 10, 'criterion': 'gini'}
# 0.675 (+/-0.049) for {'n_estimators': 100, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'entropy'}
# 0.670 (+/-0.036) for {'n_estimators': 30, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'entropy'}
# 0.656 (+/-0.034) for {'n_estimators': 30, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'entropy'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.69      0.64      0.66      2352
#         1.0       0.70      0.75      0.72      2648
#
# avg / total       0.70      0.70      0.70      5000
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'gini'}
#
# Grid scores on development set:
#
# 0.663 (+/-0.051) for {'n_estimators': 30, 'min_samples_split': 2, 'max_depth': 5, 'criterion': 'gini'}
# 0.659 (+/-0.035) for {'n_estimators': 50, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'gini'}
# 0.644 (+/-0.032) for {'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'gini'}
# 0.642 (+/-0.053) for {'n_estimators': 10, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'entropy'}
# 0.685 (+/-0.042) for {'n_estimators': 50, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'entropy'}
# 0.660 (+/-0.054) for {'n_estimators': 40, 'min_samples_split': 4, 'max_depth': 5, 'criterion': 'entropy'}
# 0.668 (+/-0.036) for {'n_estimators': 20, 'min_samples_split': 2, 'max_depth': 15, 'criterion': 'entropy'}
# 0.660 (+/-0.035) for {'n_estimators': 30, 'min_samples_split': 9, 'max_depth': 5, 'criterion': 'gini'}
# 0.650 (+/-0.050) for {'n_estimators': 40, 'min_samples_split': 9, 'max_depth': 5, 'criterion': 'gini'}
# 0.690 (+/-0.033) for {'n_estimators': 100, 'min_samples_split': 4, 'max_depth': 15, 'criterion': 'gini'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.70      0.65      0.67      2352
#         1.0       0.71      0.75      0.73      2648
#
# avg / total       0.70      0.70      0.70      5000

# %%
 clf.cv_results_['mean_test_score'][0]
# Out:
# 0.6632155085113566

# %%
 clf.cv_results_['params'][0]
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_split': 2,
#  'n_estimators': 30}
